# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
student=pd.read_csv('/content/drive/MyDrive/principles of data science lab/sample.csv')
student
# Out:
#    stud_ID    stud_name Department  Physics  Mathematics  com.sci  Totalscore
# 0       S1       Sonali        Msc       88           79     90.0         257
# 1       S2       Raksha        Msc       70           66     89.0         225
# 2       S3      Gautham        Msc       78           55     79.0         212
# 3       S4       Sonith        Msc       34           80      NaN         114
# 4       S5    Siddharth        Msc       90           93     55.0         238
# 5       S6        Isana        Msc       77           67     54.0         198
# 6       S7     Hifazath        Msc       88           87     74.0         249
# 7       S8      Prathvi        Msc       66           95     84.0         245
# 8       S9  Jayalakshmi        Msc       59           47     88.0         194
# 9      S10     Dhanwika        Msc       76           57     89.0         222
# 10     S11     Jeethesh        MCA       84           34     90.0         208
# ...

# %%
student.head()
# Out:
#   stud_ID  stud_name Department  Physics  Mathematics  com.sci  Totalscore
# 0      S1     Sonali        Msc       88           79     90.0         257
# 1      S2     Raksha        Msc       70           66     89.0         225
# 2      S3    Gautham        Msc       78           55     79.0         212
# 3      S4     Sonith        Msc       34           80      NaN         114
# 4      S5  Siddharth        Msc       90           93     55.0         238

# %%
student.tail(6)
# Out:
#    stud_ID    stud_name Department  Physics  Mathematics  com.sci  Totalscore
# 14     S15   Netravathi        MCA       39           85     88.0         212
# 15     S16     Sushanth        MCA       40           71     45.0         156
# 16     S17      Sandhya        MCA       49           88     33.0         170
# 17     S18        Pooja        MCA       77           83     76.0         236
# 18     S19     Harshith        MCA       88           89     77.0         254
# 19     S20  Jayalakshmi        Msc       59           47     88.0         194

# %%
student.describe(include='all')
# Out:
#        stud_ID    stud_name Department    Physics  Mathematics    com.sci  \
# count       20           20         20  20.000000    20.000000  18.000000
# unique      20           19          2        NaN          NaN        NaN
# top         S1  Jayalakshmi        Msc        NaN          NaN        NaN
# freq         1            2         11        NaN          NaN        NaN
# mean       NaN          NaN        NaN  68.950000    73.150000  75.666667
# std        NaN          NaN        NaN  18.400443    17.475622  18.009801
# min        NaN          NaN        NaN  34.000000    34.000000  33.000000
# 25%        NaN          NaN        NaN  57.750000    63.750000  68.000000
# 50%        NaN          NaN        NaN  73.000000    79.500000  81.500000
# 75%        NaN          NaN        NaN  85.000000    87.250000  88.750000
# max        NaN          NaN        NaN  94.000000    95.000000  97.000000
#
#         Totalscore
# count    20.000000
# unique         NaN
# ...

# %%
student.hist(figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'Physics'}>,
#         <Axes: title={'center': 'Mathematics'}>],
#        [<Axes: title={'center': 'com.sci'}>,
#         <Axes: title={'center': 'Totalscore'}>]], dtype=object)

# %%
sns.boxplot(x="stud_ID",y="Physics",data=student)
# Out:
# <Axes: xlabel='stud_ID', ylabel='Physics'>

# %%
sns.pairplot(student)

# %%
student=student.drop(['Mathematics'],axis=1)
student.head(5)
# Out:
#   stud_ID  stud_name Department  Physics  com.sci  Totalscore
# 0      S1     Sonali        Msc       88     90.0         257
# 1      S2     Raksha        Msc       70     89.0         225
# 2      S3    Gautham        Msc       78     79.0         212
# 3      S4     Sonith        Msc       34      NaN         114
# 4      S5  Siddharth        Msc       90     55.0         238

# %%
student=student.rename(columns={"Department":"dpt"})
student.head(4)
# Out:
#   stud_ID stud_name  dpt  Physics  com.sci  Totalscore
# 0      S1    Sonali  Msc       88     90.0         257
# 1      S2    Raksha  Msc       70     89.0         225
# 2      S3   Gautham  Msc       78     79.0         212
# 3      S4    Sonith  Msc       34      NaN         114

# %%
duplicate_rows_student=student[student.duplicated()]
print('numbers of duplicate rows:',duplicate_rows_student.shape)
# Out:
# numbers of duplicate rows: (0, 6)

# %%
student.count()
# Out:
# stud_ID       20
# stud_name     20
# dpt           20
# Physics       20
# com.sci       18
# Totalscore    20
# dtype: int64

# %%
student=student.drop_duplicates()
student.head()
# Out:
#   stud_ID  stud_name  dpt  Physics  com.sci  Totalscore
# 0      S1     Sonali  Msc       88     90.0         257
# 1      S2     Raksha  Msc       70     89.0         225
# 2      S3    Gautham  Msc       78     79.0         212
# 3      S4     Sonith  Msc       34      NaN         114
# 4      S5  Siddharth  Msc       90     55.0         238

# %%
print(student.isnull().sum())
# Out:
# stud_ID       0
# stud_name     0
# dpt           0
# Physics       0
# com.sci       2
# Totalscore    0
# dtype: int64

# %%
student=student.dropna()
student.count()
# Out:
# stud_ID       18
# stud_name     18
# dpt           18
# Physics       18
# com.sci       18
# Totalscore    18
# dtype: int64

# %%
student['Physics'].mean()
# Out:
# 69.5

# %%
import statistics
physics=[88,70,78,34,90,77]
print("the average of physics value is ",end="")
print(statistics.mean(physics))
# Out:
# the average of physics value is 72.83333333333333

# %%
student.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of    stud_ID    stud_name  dpt  Physics  com.sci  Totalscore
# 0       S1       Sonali  Msc       88     90.0         257
# 1       S2       Raksha  Msc       70     89.0         225
# 2       S3      Gautham  Msc       78     79.0         212
# 4       S5    Siddharth  Msc       90     55.0         238
# 5       S6        Isana  Msc       77     54.0         198
# 6       S7     Hifazath  Msc       88     74.0         249
# 7       S8      Prathvi  Msc       66     84.0         245
# 8       S9  Jayalakshmi  Msc       59     88.0         194
# 9      S10     Dhanwika  Msc       76     89.0         222
# 10     S11     Jeethesh  MCA       84     90.0         208
# 11     S12       Manavi  MCA       69     97.0         254
# 13     S14        Kavya  MCA       54     66.0         204
# 14     S15   Netravathi  MCA       39     88.0         212
# 15     S16     Sushanth  MCA       40     45.0         156
# ...

# %%
student['com.sci'].median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of 0     90.0
# 1     89.0
# 2     79.0
# 4     55.0
# 5     54.0
# 6     74.0
# 7     84.0
# 8     88.0
# 9     89.0
# 10    90.0
# 11    97.0
# 13    66.0
# 14    88.0
# 15    45.0
# 16    33.0
# 17    76.0
# 18    77.0
# 19    88.0
# Name: com.sci, dtype: float64>

# %%
student.Physics.value_counts().nlargest(40).plot(kind='bar',figsize=(10,5))
plt.title("umber of stdent by Physics")
plt.ylabel("number of student")
plt.xlabel("Physics");

# %%
plt.figure(figsize=(20,10))
c=student.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
# <ipython-input-33-cae2e63219ab>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c=student.corr()
#              Physics   com.sci  Totalscore
# Physics     1.000000  0.250571    0.707234
# com.sci     0.250571  1.000000    0.553506
# Totalscore  0.707234  0.553506    1.000000
